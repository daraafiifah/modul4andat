# %% [markdown]
# # WIND ROSE DIAGRAM

# %% [markdown]
# Dalam pembuatan rose diagram, dibagi kepada 3 langkah yaitu
# 1. Input data dan cek data tersebut khususnya varibel yg buat dipanggil,terus pelajarin dulu dia dimensinya gimana
# 2. Masukan data yang ada pada variabel dalam nc ke variabel buatan kita
# 3. Hitung besaran dan arah
# 4. buat rose diagram

# %%
#masukin library dulu 
from windrose import WindroseAxes
import netCDF4 as nc
import numpy as np
import pandas as pd
import math
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Input data Angin

# %%
#masukin lokasi .nc nya dimana
fn='D:/smt7/asisten andat/anginSST5.nc'
#buka file nc nya dan liat isinya ada apa aja (variabel dan dimensi)
ds=nc.Dataset(fn)
ds
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_64BIT_OFFSET data model, file format NETCDF3):
#     Conventions: CF-1.6
#     history: 2020-10-28 08:15:24 GMT by grib_to_netcdf-2.19.0: grib_to_netcdf /data/scratch/20201028-0810/6a/_mars-webmars-public-svc-blue-006-6fe5cac1a363ec1525f54343b6cc9fd8-uA7jtq.grib -o /data/scratch/20201028-0810/a3/_grib2netcdf-webmars-public-svc-blue-005-6fe5cac1a363ec1525f54343b6cc9fd8-e0IOuT.nc -utime
#     dimensions(sizes): longitude(57), latitude(42), time(124)
#     variables(dimensions): float32 longitude(longitude), float32 latitude(latitude), int32 time(time), int16 sst(time,latitude,longitude), int16 u10(time,latitude,longitude), int16 v10(time,latitude,longitude)
#     groups:

# %%
data=pd.read_excel(r'D:/smt5/andat/praktikum/modul4 andat/Modul4.xlsx',sheets='Arus Rose and Feather')
data_angin=pd.DataFrame(data, columns=['U (m/s)','V (m/s)'])
display(data_angin)
# Out:
#      U (m/s)  V (m/s)
# 0    -0.0425   0.0003
# 1    -0.0386  -0.0003
# 2    -0.0321   0.0029
# 3    -0.0363   0.0015
# 4    -0.0470  -0.0031
# ..       ...      ...
# 139  -0.0663   0.0022
# 140  -0.0725   0.0011
# 141  -0.0597  -0.0073
# 142  -0.0539   0.0043
# 143  -0.0529   0.0105
#
# [144 rows x 2 columns]

# %% [markdown]
# ## Deklarasi Variabel Data Angin
# masukin variabel dalam nc ke variabel buatan kita sendiri
#
# rose diagram itu, inputnya harus time series sedangkan pada input data kita tau kalo data yg di download merupakan data spasial makanya diambil deh satu kolom latitude dan longitudenya itu maksudnya ngambil 1 grid.

# %%
u=ds.variables['u10'][:,5,5]
v=ds.variables['v10'][:,5,5]
lon=ds.variables['longitude'][:]
lat=ds.variables['latitude'][:]
time=ds.variables['time'][:]

#melihat dimensi masing2 variabel
print('dimensi u',np.shape(u))
print('dimensi v',np.shape(v))
print('dimensi lon',np.shape(lon))
print('dimensi lat',np.shape(lat))
print('dimensi time',np.shape(time))
# Out:
# dimensi u (124,)
# dimensi v (124,)
# dimensi lon (57,)
# dimensi lat (42,)
# dimensi time (124,)

# %%
#untuk melihat data
data_angin=pd.DataFrame(u,columns=['u'])
data_angin['v']=v
display(data_angin)
# Out:
#             u         v
# 0    3.527375  0.852336
# 1    3.809779  1.692695
# 2    2.174190  2.517143
# 3    2.690518  2.682526
# 4    3.230851  2.987968
# ..        ...       ...
# 119 -3.568023  1.886762
# 120 -4.592208  3.110772
# 121 -4.140362  2.249797
# 122 -4.452889  2.263018
# 123 -3.387049  2.714795
#
# [124 rows x 2 columns]

# %% [markdown]
# ## Besaran dan Arah Angin
# untuk membuat rose diagram, data input nya harus berupa magnitudo dan arah

# %%
mag=[]
for i in range(len(data_angin)):
    rumuz=math.hypot(data_angin['U (m/s)'].iloc[i],data_angin['V (m/s)'].iloc[i])
    mag.append(rumuz)
data_angin['magnitude']=mag[:]

dir=[]
for i in range(len(data_angin)):
    rumus=180+(180/math.pi)*math.atan2(data_angin['U (m/s)'].iloc[i],data_angin['V (m/s)'].iloc[i])
    rumus=rumus%360
    dir.append(rumus)

data_angin['direction']=dir[:]

display(data_angin)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'U (m/s)'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-5d89dbdfe711> in <module>
#       1 mag=[]
#       2 for i in range(len(data_angin)):
# ----> 3     rumuz=math.hypot(data_angin['U (m/s)'].iloc[i],data_angin['V (m/s)'].iloc[i])
#       4     mag.append(rumuz)
#       5 data_angin['magnitude']=mag[:]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'U (m/s)'

# %%
mag=[]
for i in range(len(data_angin)):
    rumuz=math.hypot(data_angin['u'].iloc[i],data_angin['v'].iloc[i])
    mag.append(rumuz)
data_angin['magnitude']=mag[:]

dir=[]
for i in range(len(data_angin)):
    rumus=180+(180/math.pi)*math.atan2(data_angin['u'].iloc[i],data_angin['v'].iloc[i])
    rumus=rumus%360
    dir.append(rumus)

data_angin['direction']=dir[:]

display(data_angin)
# Out:
#             u         v  magnitude   direction
# 0    3.527375  0.852336   3.628891  256.415739
# 1    3.809779  1.692695   4.168888  246.044294
# 2    2.174190  2.517143   3.326125  220.818909
# 3    2.690518  2.682526   3.799320  225.085228
# 4    3.230851  2.987968   4.400721  227.236614
# ..        ...       ...        ...         ...
# 119 -3.568023  1.886762   4.036169  117.869775
# 120 -4.592208  3.110772   5.546646  124.113803
# 121 -4.140362  2.249797   4.712131  118.518847
# 122 -4.452889  2.263018   4.994945  116.940294
# 123 -3.387049  2.714795   4.340762  128.712949
#
# [124 rows x 4 columns]

# %% [markdown]
# ## Membuat Wind Rose

# %%
ax = WindroseAxes.from_ax()
ax.bar(data_angin['direction'], data_angin['magnitude'], normed=True, opening=0.8, edgecolor='white', blowto=False)
ax.set_title('WIND ROSE DIAGRAM PADA.......... ')
ax.set_legend(bbox_to_anchor=(-0.1, -0.01))
#plt.savefig('D:/smt7/asisten andat/windrose1.jpeg',dpi=300)

# %% [markdown]
# # CURRENT ROSE DIAGRAM
# ## Input Data Arus

# %%
#masukin lokasi .nc nya dimana
fn2='D:/smt7/asisten andat/arus5.nc4'
#buka file nc nya dan liat isinya ada apa aja (variabel dan dimensi)
ds2=nc.Dataset(fn2)
ds2
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     classification_level: UNCLASSIFIED
#     distribution_statement: Approved for public release. Distribution unlimited.
#     downgrade_date: not applicable
#     classification_authority: not applicable
#     institution: Naval Oceanographic Office
#     source: HYCOM archive file
#     history: archv2ncdf3z
#     field_type: instantaneous
#     Conventions: CF-1.0 NAVO_netcdf_v1.0
#     History: Translated to CF-1.0 Conventions by Netcdf-Java CDM (CFGridWriter2)
# Original Dataset = GLBu0.08/expt_19.1/2000; Translation Date = 2020-10-28T08:00:24.901Z
#     geospatial_lat_min: -1.1200000047683716
#     geospatial_lat_max: 4.079999923706055
#     geospatial_lon_min: 131.1199951171875
#     geospatial_lon_max: 138.0799560546875
#     dimensions(sizes): time(31), depth(1), lat(66), lon(88)
#     variables(dimensions): int16 water_u(time,depth,lat,lon), float64 time(time), float64 depth(depth), float64 lat(lat), float64 lon(lon), int16 water_v(time,depth,lat,lon)
#     groups:

# %% [markdown]
# ## Deklarasi Variabel Arus
# grid yang dipilih pada arus u dan v sama kaya grid angin aja supaya diasumsikan tempatnya deketan

# %%
u2=ds2.variables['water_u'][:,:,5,5]
v2=ds2.variables['water_v'][:,:,5,5]
lon2=ds2.variables['lon'][:]
lat2=ds2.variables['lat'][:]
time2=ds2.variables['time'][:]

#melihat dimensi masing2 variabel
print('dimensi u',np.shape(u2))
print('dimensi v',np.shape(v2))
print('dimensi lon',np.shape(lon2))
print('dimensi lat',np.shape(lat2))
print('dimensi time',np.shape(time2))
# Out:
# dimensi u (31, 1)
# dimensi v (31, 1)
# dimensi lon (88,)
# dimensi lat (66,)
# dimensi time (31,)

# %%
#untuk melihat data
data_arus=pd.DataFrame(u2,columns=['u'])
data_arus['v']=v2
display(data_arus)
# Out:
#         u      v
# 0   0.122 -0.027
# 1   0.138 -0.079
# 2   0.066 -0.065
# 3   0.015  0.026
# 4  -0.021 -0.002
# 5   0.061 -0.008
# 6   0.100 -0.002
# 7  -0.017  0.019
# 8  -0.035  0.058
# 9  -0.094  0.104
# 10 -0.138  0.072
# 11 -0.091  0.043
# 12 -0.090  0.038
# 13 -0.096  0.045
# 14 -0.049  0.015
# 15 -0.100 -0.003
# 16  0.007  0.013
# 17  0.038  0.032
# 18 -0.045  0.047
# 19 -0.071  0.017
# 20  0.081  0.014
# 21  0.081  0.014
# 22  0.015 -0.002
# 23  0.049  0.033
# 24 -0.076  0.009
# 25  0.035  0.035
# 26 -0.068  0.016
# 27 -0.029 -0.013
# 28  0.010 -0.073
# 29  0.062 -0.051
# 30 -0.021 -0.004

# %% [markdown]
# ## Besaran dan Arah Arus

# %%
mag2=[]
for i in range(len(data_arus)):
    rumuz2=math.hypot(data_arus['u'].iloc[i],data_arus['v'].iloc[i])
    mag2.append(rumuz2)
data_arus['magnitude']=mag2[:]

dir2=[]
for i in range(len(data_arus)):
    rumus2=180+(180/math.pi)*math.atan2(data_arus['u'].iloc[i],data_arus['v'].iloc[i])
    rumus2=rumus2%360
    dir2.append(rumus2)
data_arus['direction']=dir2[:]

display(data_arus)
# Out:
#         u      v  magnitude   direction
# 0   0.122 -0.027   0.124952  282.479071
# 1   0.138 -0.079   0.159013  299.789573
# 2   0.066 -0.065   0.092634  314.562639
# 3   0.015  0.026   0.030017  209.981640
# 4  -0.021 -0.002   0.021095   84.559668
# 5   0.061 -0.008   0.061522  277.471559
# 6   0.100 -0.002   0.100020  271.145763
# 7  -0.017  0.019   0.025495  138.179830
# 8  -0.035  0.058   0.067742  148.891192
# 9  -0.094  0.104   0.140186  137.891269
# 10 -0.138  0.072   0.155653  117.552811
# 11 -0.091  0.043   0.100648  115.292021
# 12 -0.090  0.038   0.097693  112.890552
# 13 -0.096  0.045   0.106024  115.114836
# 14 -0.049  0.015   0.051245  107.020525
# 15 -0.100 -0.003   0.100045   88.281642
# 16  0.007  0.013   0.014765  208.300756
# 17  0.038  0.032   0.049679  229.899093
# 18 -0.045  0.047   0.065069  136.245364
# 19 -0.071  0.017   0.073007  103.465208
# 20  0.081  0.014   0.082201  260.193907
# 21  0.081  0.014   0.082201  260.193907
# 22  0.015 -0.002   0.015133  277.594643
# 23  0.049  0.033   0.059076  236.040942
# 24 -0.076  0.009   0.076531   96.753574
# 25  0.035  0.035   0.049497  225.000000
# 26 -0.068  0.016   0.069857  103.240520
# 27 -0.029 -0.013   0.031780   65.854458
# 28  0.010 -0.073   0.073682  352.199812
# 29  0.062 -0.051   0.080281  309.440053
# 30 -0.021 -0.004   0.021378   79.215702

# %% [markdown]
# ## Membuat Current Rose

# %%
ax = WindroseAxes.from_ax()
ax.bar(data_arus['direction'], data_arus['magnitude'], normed=True, opening=0.8, edgecolor='white', blowto=True)
ax.set_title('CURRENT ROSE DIAGRAM')
ax.set_legend(bbox_to_anchor=(-0.1, -0.01))
#plt.savefig('D:/smt7/asisten andat/currentrose1.jpeg',dpi=300)
